# %%
import polars as pl
import main

# %%
df:pl.DataFrame = main.get_data()

# %%
print(df)
# Out:
# shape: (211, 5)
# ┌────────────┬───────┬─────────┬──────────┬──────────────────┐
# │ date       ┆ cost  ┆ gallons ┆ odometer ┆ price_per_gallon │
# │ ---        ┆ ---   ┆ ---     ┆ ---      ┆ ---              │
# │ date       ┆ f64   ┆ f64     ┆ f64      ┆ f64              │
# ╞════════════╪═══════╪═════════╪══════════╪══════════════════╡
# │ 2018-12-08 ┆ 30.0  ┆ 8.672   ┆ 49662.0  ┆ 2.839            │
# │ 2018-12-21 ┆ 30.0  ┆ 8.672   ┆ 49934.0  ┆ 2.839            │
# │ 2019-01-12 ┆ 24.62 ┆ 8.672   ┆ 50396.0  ┆ 2.839            │
# │ 2019-02-15 ┆ 26.35 ┆ 9.55    ┆ 50666.0  ┆ 2.759            │
# │ 2019-03-14 ┆ 28.17 ┆ 9.786   ┆ 50921.0  ┆ 2.879            │
# │ …          ┆ …     ┆ …       ┆ …        ┆ …                │
# │ 2026-03-01 ┆ 18.62 ┆ 5.4     ┆ 105050.0 ┆ 3.449            │
# │ 2026-03-14 ┆ 47.3  ┆ 10.065  ┆ 105323.0 ┆ 4.699            │
# │ 2026-03-26 ┆ 50.25 ┆ 9.665   ┆ 105575.0 ┆ 5.199            │
# │ 2026-04-03 ┆ 51.35 ┆ 9.954   ┆ 105743.0 ┆ 5.159            │
# ...

# %%
main.plot_all(df=df)

# %%
main.plot_cost_per_mile(df=df)
